# %%
#User pass catalog
try:
	catalog=dbutils.widgets.get("catalog")
except Exception:
	catalog="travel_bookings"

#User pass schema
try:
	schema=dbutils.widgets.get("schema")
except Exception:
	schema="default"

# %%
#Analyze statistics on booking fact table
spark.sql(f"analyze table {catalog}.{schema}.booking_fact compute statistics for all column")
